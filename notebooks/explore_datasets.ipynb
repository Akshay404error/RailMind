# %% [markdown]
# # Explore raw datasets
# Load whatever you placed in `data/raw/` and inspect structure before writing the loader.

# %%
import pandas as pd
import json
import os

RAW_DIR = '../data/raw'
print(os.listdir(RAW_DIR))

# %%
# If you have a JSON schedule/station file, load and inspect it
# with open(f'{RAW_DIR}/indian_railways_dataset.json') as f:
#     data = json.load(f)
# print(type(data), len(data))
# data[0] if isinstance(data, list) else list(data.items())[:1]

# %%
# If you have a delays CSV, load and inspect it
# df = pd.read_csv(f'{RAW_DIR}/train_delays.csv')
# df.head()
# df.columns
